# %% [markdown]
# ## Dataset Overview and Cleaning Verification
#
# The dataset contains **17,686 entries** with 9 columns:
#
# | Column            | Description                     | Data Type |
# |------------------|---------------------------------|-----------|
# | Person_ID         | Unique identifier for each person | Integer   |
# | Age               | Age of the person               | Integer   |
# | Gender            | Gender of the person            | String    |
# | Region            | Geographic region               | String    |
# | Diet_Type         | Type of diet followed           | String    |
# | Health_Impact     | Reported health effects         | String    |
# | Common_Diseases   | List of common diseases         | String    |
# | Exercise_Level    | Level of physical activity      | String    |
# | BMI               | Body Mass Index                 | Float     |
#
# ### Cleaning Workflow
# 1. **Data Cleaning in Power Query (Excel):**
#    - Removed duplicates and empty rows.
#    - Corrected inconsistencies in text fields (extra spaces, capitalization).
#    - Standardized categorical values (`Gender`, `Diet_Type`, `Exercise_Level`).
#    - Ensured numeric columns like `Age` and `BMI` are valid and consistent.
#
# 2. **Verification in Python (pandas):**
#    - Checked for **missing values** across all columns.
#    - Ensured **datatypes are consistent**.
#    - Confirmed **no duplicates remain**.
#
# ### Summary
# - Raw dataset was cleaned using **Power Query** for efficiency and automation.
# - Python verification ensured the dataset is **consistent, complete, and ready for analysis**.
# - Final dataset: **17,686 entries** and **9 clean columns**, suitable for visualization, statistical analysis, or predictive modeling.

# %%
import pandas as pd

# %%
file_path = "C:/Users/Chandru R/Desktop/Document/Cleaned Excel DataSet/2024 Past Data/food_impact_india_2024.xlsx"  

df = pd.read_excel(file_path)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17686 entries, 0 to 17685
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Person_ID        17686 non-null  int64
#  1   Age              17686 non-null  int64
#  2   Gender           17686 non-null  object
#  3   Region           17686 non-null  object
#  4   Diet_Type        17686 non-null  object
#  5   Health_Impact    17686 non-null  object
#  6   Common_Diseases  17686 non-null  object
#  7   Exercise_Level   17686 non-null  object
#  8   BMI              17686 non-null  float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 1.2+ MB

# %%
df.shape
# Out:
# (17686, 9)
