# %% [markdown]
# ## Dataset Overview and Cleaning Verification
#
# The dataset contains **973 entries** with 9 columns:
#
# | Column                        | Description                             | Data Type |
# |-------------------------------|-----------------------------------------|-----------|
# | Age                           | Age of the gym member                   | Integer   |
# | Gender                        | Gender of the gym member                | String    |
# | Weight(kg)                    | Body weight in kilograms                | Float     |
# | Session_Duration(hours)       | Duration of workout sessions            | Float     |
# | Workout_Type                  | Type of workout performed               | String    |
# | Fat_Percentage                | Body fat percentage                      | Float     |
# | Water_Intake(liters)          | Daily water intake in liters            | Float     |
# | Workout_Frequency(days/week)  | Number of workout days per week         | Integer   |
# | BMI                           | Body Mass Index                          | Float     |
#
# ### Cleaning Workflow
# 1. **Data Cleaning in Power Query (Excel):**
#    - Removed duplicate and empty rows.
#    - Trimmed extra spaces and standardized text capitalization.
#    - Standardized categorical columns (`Gender`, `Workout_Type`).
#    - Ensured numeric columns (`Weight`, `Session_Duration`, `Fat_Percentage`, `BMI`) are valid and consistent.
#
# 2. **Verification in Python (pandas):**
#    - Checked for **missing values** in all columns.
#    - Verified **datatypes** match expectations.
#    - Confirmed **no duplicates remain**.
#    - Ensured the **table structure** is intact.
#
# ### Summary
# - Raw dataset was cleaned using **Power Query** for efficiency and automation.
# - Python verification ensures the dataset is **consistent, complete, and ready for analysis**.
# - Final dataset contains **973 clean entries** and **9 columns**, suitable for visualization, analysis, or modeling.

# %%
import pandas as pd

# %%
file_path = "C:/Users/Chandru R/Desktop/Document/Cleaned Excel DataSet/2024 Past Data/gym_members_exercise_tracking_approximate_data(2024).xlsx"  

df = pd.read_excel(file_path)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           973 non-null    int64
#  1   Gender                        973 non-null    object
#  2   Weight(kg)                    973 non-null    float64
#  3   Session_Duration(hours)       973 non-null    float64
#  4   Workout_Type                  973 non-null    object
#  5   Fat_Percentage                973 non-null    float64
#  6   Water_Intake(liters)          973 non-null    float64
#  7   Workout_Frequency(days/week)  973 non-null    int64
#  8   BMI                           973 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 68.5+ KB

# %%
df.shape
# Out:
# (973, 9)
